# %% [markdown]
# ### 제어문 if문
#
# #### 1. 단순 if문
# <img src="./images/09.제어문_if_01_단순if문.png" width = "800 height = "600">
#
# #### 2. if ~ else문
# <img src="./images/09.제어문_if_01_if_else문.png" width = "800 height = "600">
#
# #### 3. if ~ elif ~ else문
# <img src="./images/09.제어문_if_01_if_elif_else문.png" width = "800 height = "600">

# %%
from sys import set_coroutine_origin_tracking_depth

money = True
if money:
    print("택시를 타고 가라")
else:
    print("걸어가라")
# Out:
# 택시를 타고 가라

# %% [markdown]
# if문의 기본 구조
# if 조건문:
#     수행할문장
#     수행할문장
# else:
#     수행할문장
#     수행할문장

# %% [markdown]
# 조건문이란 무엇인가?

# %%
money = True
if money:

# %%
x = 3
y = 2
x > y
# Out:
# True

# %%
x < y
# Out:
# False

# %%
x != y
# Out:
# True

# %%
money = 2000
if money >= 3000:
    print("택시를 타고 가라")
else:
    print("걸어가라")
# Out:
# 걸어가라

# %%
money = 2000
card = True
if money >= 3000 or card:
    print("택시를 타고 가라")
else:
    print("걸어가라")
# Out:
# 택시를 타고 가라

# %% [markdown]
# in, not in

# %%
1 in [1, 2, 3]
# Out:
# True

# %%
1 not in [1,2,3]
# Out:
# False

# %%
'a' in ('a','b','c')
# Out:
# True

# %%
'j' not in 'python'
# Out:
# True

# %%
pocket = ['paper', 'cellphone', 'money']
if 'money' in pocket:
    print("택시를 타고 가라")
else:
    print("걸어가라")
# Out:
# 택시를 타고 가라

# %%
pocket = ['paper', 'money', 'cellphone']
if 'money' in pocket:
    pass
else:
    print('카드를 꺼내라')

# %% [markdown]
# 다양한 조건을 판단하는 elif

# %%
pocket = ['paper', 'cellphone']
card = True
if 'money' in pocket:
    print("택시를 타고 가라")
elif card:
    print("택시를 타고 가라")
else:
    print("걸어가라")
# Out:
# 택시를 타고 가라

# %% [markdown]
# if문을 한 줄로 작성하기

# %%
pocket = ['paper', 'money', 'cellphone']
if 'money' in pocket: pass
else: print("카드를 꺼내라")

# %% [markdown]
# 조건부 표현식

# %%
# if score >= 60:
#     message = "success"
# else:
#     message = "failure"
#
# 조건부 표현식을 사용해 간단히 표현
# message = "success" if score >= 60 else "failure"
#
# 조건부 표현식은 다음과 같이 정의
# 변수 = 조건문이_참인_경우의_값 if 조건문 else 조건문이_거짓인_경우의_값

# %%
score = 85
result = "합격" if score >= 60 else "불합격"
print(result)
# Out:
# 합격

# %% [markdown]
# 이런 간단한 조건 분기는 파이썬의 조건부 표현식을 사용하면 한 줄로 표현할 수 있다.
# * 조건부 표현식의 기본 형태(아래참조)
#
# 변수 = 참일_때_값 if 조건 else 거짓일_때_값
