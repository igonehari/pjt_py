# %% [markdown]
# #### 데이터분석 라이브러리
#
# #### 1. Python의 주요 데이터분석 라이브러리(패키지)
#
# > 1. `numpy` : 데이터분석의 기본적인 기능을 제공, 특히 `벡터와행렬`연산 관련 기능을 제공
# > 2. `pandas` : 1차원 자료구조(`Series`)와 2차원자료구조(`DataFrame`)를 이용해서 데이터분석에 우수한 성능을 발휘한다. 대용량의 데이터를 보다 빠르게 처리할 수 있도록 지원한다.
# > 3. `matploglib` : 데이터 분석 결과에 대한 `시각화를 빠르고 직관적으로 수행`한다.
#
# #### 2. Package설치 방법
# > * `pip install numpy`
# > * `pip install pandas`
# > * `pip install matplotlib`
#
# #### 3. 설치된 패키목록 보기
# > * `pip list` or `conda list`
#
# #### 4. 참고 사이트
# * https://numpy.org
# * https://pandas.pydata.org
# * https://matplotlib.org

# %%
# %pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-3.0.5-cp314-cp314-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=2.3.3 in d:\lsk\pjt_py\.venv\lib\site-packages (from pandas) (2.5.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\lsk\pjt_py\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in d:\lsk\pjt_py\.venv\lib\site-packages (from pandas) (2026.3)
# Requirement already satisfied: six>=1.5 in d:\lsk\pjt_py\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-3.0.5-cp314-cp314-win_amd64.whl (10.0 MB)
#    ---------------------------------------- 0.0/10.0 MB ? eta -:--:--
#    -------------------------- ------------- 6.6/10.0 MB 33.3 MB/s eta 0:00:01
#    ---------------------------------------- 10.0/10.0 MB 23.9 MB/s eta 0:00:00
# Installing collected packages: pandas
# Successfully installed pandas-3.0.5
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 26.2.1
# [notice] To update, run: D:\LSK\pjt_py\.venv\Scripts\python.exe -m pip install --upgrade pip

# %%
# ! conda list

# %% [markdown]
# #### %매직명령어
#
# * %pwd
# * %ls
# * %who or %whos
# * %hist
# * `%matpotlib` : 그래프출력을 웹에 완성된 형태로 출력할 것인지 인터렉티브형태로 출력할 것인 여부

# %%
import numpy as np
import pandas as pd
# import matplot
import matplotlib.pyplot as plt

# %whos
# Out:
# Variable             Type      Data/Info
# ----------------------------------------
# np                   module    <module 'numpy' from 'C:\<...>ges\\numpy\\__init__.py'>
# pd                   module    <module 'pandas' from 'C:<...>es\\pandas\\__init__.py'>
# plt                  module    <module 'matplotlib.pyplo<...>\\matplotlib\\pyplot.py'>
# pydev_jupyter_vars   module    <module 'pydev_jupyter_va<...>\\pydev_jupyter_vars.py'>

# %%
# print(dir(np))
print()
print(dir(pd))
print()
# print(dir(matplotlib))
# Out:
# ['ArrowDtype', 'BooleanDtype', 'Categorical', 'CategoricalDtype', 'CategoricalIndex', 'DataFrame', 'DateOffset', 'DatetimeIndex', 'DatetimeTZDtype', 'ExcelFile', 'ExcelWriter', 'Flags', 'Float32Dtype', 'Float64Dtype', 'Grouper', 'HDFStore', 'Index', 'IndexSlice', 'Int16Dtype', 'Int32Dtype', 'Int64Dtype', 'Int8Dtype', 'Interval', 'IntervalDtype', 'IntervalIndex', 'MultiIndex', 'NA', 'NaT', 'NamedAgg', 'Period', 'PeriodDtype', 'PeriodIndex', 'RangeIndex', 'Series', 'SparseDtype', 'StringDtype', 'Timedelta', 'TimedeltaIndex', 'Timestamp', 'UInt16Dtype', 'UInt32Dtype', 'UInt64Dtype', 'UInt8Dtype', '__all__', '__builtins__', '__cached__', '__doc__', '__docformat__', '__file__', '__git_version__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', '_built_with_meson', '_config', '_is_numpy_dev', '_libs', '_pandas_datetime_CAPI', '_pandas_parser_CAPI', '_testing', '_typing', '_version_meson', 'annotations', 'api', 'array', 'arrays', 'bdate_range', 'col', 'compat', 'concat', 'core', 'crosstab', 'cut', 'date_range', 'describe_option', 'errors', 'eval', 'factorize', 'from_dummies', 'get_dummies', 'get_option', 'infer_freq', 'interval_range', 'io', 'isna', 'isnull', 'json_normalize', 'lreshape', 'melt', 'merge', 'merge_asof', 'merge_ordered', 'notna', 'notnull', 'offsets', 'option_context', 'options', 'pandas', 'period_range', 'pivot', 'pivot_table', 'plotting', 'qcut', 'read_clipboard', 'read_csv', 'read_excel', 'read_feather', 'read_fwf', 'read_hdf', 'read_html', 'read_iceberg', 'read_json', 'read_orc', 'read_parquet', 'read_pickle', 'read_sas', 'read_spss', 'read_sql', 'read_sql_query', 'read_sql_table', 'read_stata', 'read_table', 'read_xml', 'reset_option', 'set_eng_float_format', 'set_option', 'show_versions', 'test', 'testing', 'timedelta_range', 'to_datetime', 'to_numeric', 'to_pickle', 'to_timedelta', 'tseries', 'unique', 'util', 'wide_to_long']

# %%
# A. numpy

# 1. 난수발생
# print(dir(np.random))

data = np.random.rand()
print(data, type(data))

data = np.random.rand(50)
print(data, type(data))
# Out:
# 0.04648189905805422 <class 'float'>
# [0.48808472 0.04289558 0.9599605  0.90640153 0.69440527 0.66591454
#  0.75415172 0.22642663 0.60284397 0.43356119 0.95693562 0.62206121
#  0.68685723 0.73897579 0.50207189 0.042466   0.80951134 0.53755046
#  0.02164533 0.39573085 0.23872521 0.97386445 0.5929611  0.79429833
#  0.20424315 0.17306531 0.45407057 0.82333425 0.99840487 0.33167034
#  0.24262024 0.44685864 0.71256246 0.32411251 0.53656936 0.6170688
#  0.79948582 0.0769137  0.61477006 0.43939458 0.98597754 0.33359106
#  0.7057881  0.60632722 0.5133063  0.35047714 0.13798772 0.55099995
#  0.79521114 0.97689614] <class 'numpy.ndarray'>

# %%
# B. pandas
# 1. 1차원 자료 : Series

data = np.random.rand(50)

s = pd.Series(data)
print(s, type(s))
# Out:
# 0     0.705296
# 1     0.290177
# 2     0.265570
# 3     0.346596
# 4     0.600562
# 5     0.685687
# 6     0.243556
# 7     0.468081
# 8     0.248189
# 9     0.417949
# 10    0.458160
# 11    0.058273
# 12    0.638491
# 13    0.613224
# 14    0.995872
# 15    0.294209
# 16    0.218058
# 17    0.827747
# 18    0.433212
# 19    0.035333
# 20    0.265867
# 21    0.294696
# 22    0.851106
# 23    0.353560
# 24    0.724561
# 25    0.591161
# 26    0.699211
# 27    0.099944
# 28    0.345766
# 29    0.012272
# 30    0.935554
# 31    0.969236
# 32    0.999458
# 33    0.477211
# 34    0.422243
# 35    0.629294
# 36    0.310714
# 37    0.243387
# 38    0.806441
# 39    0.561094
# 40    0.923861
# 41    0.371695
# 42    0.745079
# 43    0.696043
# 44    0.730830
# 45    0.299314
# 46    0.595304
# 47    0.739635
# 48    0.458144
# 49    0.320474
# dtype: float64 <class 'pandas.Series'>

# %%
# %matplotlib inline
# 시각화(pandas 고유기능으로 시각화) - ndarray로 시각화

s.plot()
# Out:
# <Axes: >

# %%
# 2. 2차원 자료 : DataFrame

df = pd.DataFrame(data)
print(df, type(df))

display(df, type(df))
# Out:
#            0
# 0   0.488085
# 1   0.042896
# 2   0.959961
# 3   0.906402
# 4   0.694405
# 5   0.665915
# 6   0.754152
# 7   0.226427
# 8   0.602844
# 9   0.433561
# 10  0.956936
# 11  0.622061
# 12  0.686857
# 13  0.738976
# 14  0.502072
# 15  0.042466
# 16  0.809511
# 17  0.537550
# 18  0.021645
# 19  0.395731
# 20  0.238725
# 21  0.973864
# 22  0.592961
# 23  0.794298
# 24  0.204243
# 25  0.173065
# 26  0.454071
# 27  0.823334
# 28  0.998405
# 29  0.331670
# 30  0.242620
# 31  0.446859
# 32  0.712562
# 33  0.324113
# 34  0.536569
# 35  0.617069
# 36  0.799486
# 37  0.076914
# 38  0.614770
# 39  0.439395
# 40  0.985978
# 41  0.333591
# 42  0.705788
# 43  0.606327
# 44  0.513306
# 45  0.350477
# 46  0.137988
# 47  0.551000
# 48  0.795211
# 49  0.976896 <class 'pandas.DataFrame'>
#            0
# 0   0.488085
# 1   0.042896
# 2   0.959961
# 3   0.906402
# 4   0.694405
# 5   0.665915
# 6   0.754152
# 7   0.226427
# 8   0.602844
# 9   0.433561
# 10  0.956936
# 11  0.622061
# 12  0.686857
# 13  0.738976
# 14  0.502072
# 15  0.042466
# 16  0.809511
# 17  0.537550
# 18  0.021645
# 19  0.395731
# 20  0.238725
# 21  0.973864
# 22  0.592961
# 23  0.794298
# 24  0.204243
# 25  0.173065
# 26  0.454071
# 27  0.823334
# 28  0.998405
# 29  0.331670
# 30  0.242620
# 31  0.446859
# 32  0.712562
# 33  0.324113
# 34  0.536569
# 35  0.617069
# 36  0.799486
# 37  0.076914
# 38  0.614770
# 39  0.439395
# 40  0.985978
# 41  0.333591
# 42  0.705788
# 43  0.606327
# 44  0.513306
# 45  0.350477
# 46  0.137988
# 47  0.551000
# 48  0.795211
# 49  0.976896
# pandas.DataFrame

# %%
df.plot()
# Out:
# <Axes: >

# %%
# numpy로 랜덤하게 10*3열의 2차원배열(행렬 만들기)

data = np.random.rand(10, 3)
print(data, type(data))
# Out:
# [[0.8023161  0.58988189 0.36216947]
#  [0.1569531  0.59334947 0.04356519]
#  [0.31140205 0.23041857 0.95949285]
#  [0.74359889 0.67475655 0.94152908]
#  [0.46356876 0.59280726 0.4193464 ]
#  [0.17117129 0.00223497 0.79261431]
#  [0.04509899 0.3391484  0.52036022]
#  [0.01101238 0.31473675 0.12253248]
#  [0.270332   0.80146711 0.19190171]
#  [0.08440535 0.39152452 0.90909366]] <class 'numpy.ndarray'>

# %%
df = pd.DataFrame(data)
display(df, type(df))
# Out:
#           0         1         2
# 0  0.802316  0.589882  0.362169
# 1  0.156953  0.593349  0.043565
# 2  0.311402  0.230419  0.959493
# 3  0.743599  0.674757  0.941529
# 4  0.463569  0.592807  0.419346
# 5  0.171171  0.002235  0.792614
# 6  0.045099  0.339148  0.520360
# 7  0.011012  0.314737  0.122532
# 8  0.270332  0.801467  0.191902
# 9  0.084405  0.391525  0.909094
# pandas.DataFrame

# %%
df = pd.DataFrame(data, columns=['2018','2019','2020'])
display(df)
# Out:
#        2018      2019      2020
# 0  0.802316  0.589882  0.362169
# 1  0.156953  0.593349  0.043565
# 2  0.311402  0.230419  0.959493
# 3  0.743599  0.674757  0.941529
# 4  0.463569  0.592807  0.419346
# 5  0.171171  0.002235  0.792614
# 6  0.045099  0.339148  0.520360
# 7  0.011012  0.314737  0.122532
# 8  0.270332  0.801467  0.191902
# 9  0.084405  0.391525  0.909094

# %%
# 2차원 자료로 시각화
df.plot()
# Out:
# <Axes: >

# %%
# bar
df.plot(kind = 'bar')
# Out:
# <Axes: >

# %%
# barh

df.plot(kind='barh')
# Out:
# <Axes: >

# %%
# area

df.plot(kind = 'area')
df.plot(kind = 'area', stacked = False)
# Out:
# <Axes: >

# %%
# pie
s = pd.Series(data=np.random.rand(5), index = [2015,2016,2017,2018,2019])
s.plot(kind = 'pie', fontsize=11, title = 'sales test', figsize=(10,5), autopct = "%.2f%%")
# Out:
# <Axes: title={'center': 'sales test'}>
