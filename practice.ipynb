# %% [markdown]
# ### A. Jupyter Notebook 기본 사용법
#
# #### 1. 새 파일 생성
#
# 1. 프로젝트 폴더 선택 --> [+] --> 'jupyter notebook' 클릭 --> new jupyter notebook --> 이름 입력 --> 새 파일 생성.
# 2.  생성된 파일의 이름을 변경하려면 제목 선택 --> rename --> 이름을 변경하면 된다.
#
# #### 2. 셀의 타입
# 셀의 타입 `Code 타입`, `Markdown 타입`이 있다. `Code타입은 파이썬의 코드를 실행`할 수 있는 셀이다. 기본적인 생성 셀은 Code 타입으로 생성된다. Markdown 타입은 `주석으로 셀의 내용`을 작성 할 수 있다
#
# #### 3. 셀 실행
# 1. `shift + enter`(현재 셀 실행 후 다음셀로 이동), `ctrl + enter`(현재 셀 실행만)
# 2. 실행한 후에 셀 아래쪽에 실행 결과가 출력이 된다.

# %% [markdown]
# #### 사칙연산

# %%
1 + 2
# Out:
# 3

# %% [markdown]
# #### 나눗셈

# %%
3 / 2.4
3 * 9
# Out:
# 27

# %% [markdown]
# #### 변수에 숫자 대입하고 계산하기

# %%
a = "Python"
print(a)
# Out:
# Python

# %% [markdown]
# #### 조건문 if

# %%
a = 3
if a > 1:
    print("a는 1보다 크다")
# Out:
# a는 1보다 크다

# %% [markdown]
# #### 반복문 while

# %%
i = 0
while i < 3:
    i = i + 1
    print(i)
# Out:
# 1
# 2
# 3

# %% [markdown]
# #### 함수

# %%
def add(a,b):
    return a+b
add (3,7)
# Out:
# 10
