# %% [markdown]
# ### 예외처리(Exception)
#
# #### 1. ㅇ에러와 예외
#
# 1. 에러(Syntex Error) : 문법에러, 파이썬은 상대적으로 문법이 간단하기 때문에 구문자체 에러 즉, 문법에러 발생비율이 적다.
# 2. 예외(Exception) : 예외는 실행중에 발생하는 에러로서 문법에러는 없으나 프로그램이 실행중에 더 이상 진행할 수 가 없는 상태를 말한다. 예외가 발생이 되면 프로그램이 바로 중단이 된다. 이런 중단이 되는 상황을 방지하기 위해 예외처리를 해야한다.
#
# #### 2. 예외처리 방법
#
# > `try:` <br>
#     예외가 발생할 가능이 있는 실행문자.... (예를 들면 c = b / 0) <br>
# > `except Exception:` <br>
#     예외가 발생했을 경우 실행할 문자.... (print('0으로 나눌 수 없습니다.') <br>
# > `else` <br>
#     정상적으로 처리할 경우의 실행할 문자 <br>
# > `finally:` <br>
#     한번은 반드시 실행해야 할 문자
#
# #### 3. 예외발생과 except
#
# <img src='./images/17.예외처리_exception_01.png' width = "800" height = "600">
#
# #### 4. 파이썬 예외 계층도
# <img src='./images/17.예외처리_exception_02.png' width = "800" height = "600">

# %%
from soupsieve.css_types import pickle_register

f = open("나없는파일", 'r')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 f = open("나없는파일", 'r')
#
# FileNotFoundError: [Errno 2] No such file or directory: '나없는파일'

# %%
4 / 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 4 / 0
#
# ZeroDivisionError: division by zero

# %%
a = [1, 2, 3]
a[3]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[4], line 2
#       1 a = [1, 2, 3]
# ----> 2 a[3]
#
# IndexError: list index out of range

# %% [markdown]
# 오류 예외 처리 기법

# %% [markdown]
# try-except문
# ```
# try
#     ...
# except [발생오류_오류 [as 오류_변수]]
#     ...
# ```

# %% [markdown]
# 1. try-except만 쓰는 방법
# ```
# try:
#     ...
# except:
#     ...
# ```

# %% [markdown]
# 2. 발생 오류만 포함한 except문
# ```
# try:
#     ...
# except 발생_오류:
#     ...
# ```

# %% [markdown]
# 3. 발생 오류와 오류 변수까지 포함한 except문
# ```
# try:
#     ...
# except 발생_오류 as 오류_변수:
#     ...
# ```

# %%
# try_except.py
try:
    4 / 0
except ZeroDivisionError as e:
    print(e)
# Out:
# division by zero

# %% [markdown]
# try-finally문

# %%
# try_finally.py

try:
    f = open('foo.txt', 'w')
    #무언가를 수행
    # (...생략...)

finally:
    f.close()

# %% [markdown]
# 여러개의 오류 처리하기
# ```
# try:
#     ...
# except 발생_오류1:
#     ...
# except 발생_오류:
#     ...

# %%
# many_error.py

try:
    a = [1, 2]
    print(a[3])
    4 / 0

except ZeroDivisionError:
    print("0으로 나눌 수 없습니다.")

except IndexError:
    print("인덱싱할 수 없습니다.")
# Out:
# 인덱싱할 수 없습니다.

# %% [markdown]
# try-else문
# ```
# try:
#     ...
# except [발생_오류 [as 오류_변수]]:
#     ...
# else:
#     ...
# ```

# %%
# try_else.py

try:
    age = int(input('나이를 입력하세요: '))
except:
    print('입력이 정확하지 않습니다.')
else:
    if age <= 18:
        print('미성년자는 출입금지입니다.')
    else:
        print('환영합니다')
# Out:
# 입력이 정확하지 않습니다.

# %% [markdown]
# 오류 회피하기

# %%
# error_pass.py

try:
    f = open("나없는파일", 'r')
except FileExistsError:
    pass

# %% [markdown]
# 오류 일부러 발생시키기

# %%
# error_raise.py

class Bird:
    def fly(self):
        raise NotImplementedError

class Eagle(Bird):
    def fly(self):
        print("very fast")

eagle = Eagle()
eagle.fly()
# Out:
# very fast

# %% [markdown]
# 예외 만들기

# %%
# error_make.py
class MyError(Exception):
    def __str__(self):
        return "허용되지 않는 별명입니다."

def say_nick(nick):
    if nick == "바보":
        raise MyError()
    print(nick)

try:
    say_nick("천사")
    say_nick("바보")

# except MyError:
#     print("허용되지 않는 별명입니다.")
except MyError as e:
    print(e)
# Out:
# 천사
# 허용되지 않는 별명입니다.
