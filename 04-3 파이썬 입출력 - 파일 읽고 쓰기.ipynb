# %% [markdown]
# ### 파일 생성하기

# %%
# newfile.py
f = open("새파일.txt", 'w')
f.close()

# %% [markdown]
# 프로그램을 실행한 디렉터리에 새로운 파일이 하나 생성된 것을 확인할 수 있을 것이다.
# * 새파일.txt --> 생성 경로 --> 상대경로

# %%
# newfiel2.py
f = open("C:/doit/새파일.txt", 'w')
f.close()

# %% [markdown]
# c:\doit --> 폴더 생성은? --> 사용자

# %%
# write_data.py

# %%
# write_data.py
f = open("C:/doit/새파일.txt", 'w')
for i in range(1, 11):
    data = f"{i}번째 줄입니다.\n"
    f.write(data)  # 파일 출력
f.close()

# %%
for i in range(1, 11):
    data = f"{i}번째 줄 입니다.\n"
    print(data) # 화면 출력
# Out:
# 1번째 줄 입니다.
#
# 2번째 줄 입니다.
#
# 3번째 줄 입니다.
#
# 4번째 줄 입니다.
#
# 5번째 줄 입니다.
#
# 6번째 줄 입니다.
#
# 7번째 줄 입니다.
#
# 8번째 줄 입니다.
#
# 9번째 줄 입니다.
#
# 10번째 줄 입니다.

# %% [markdown]
# ### 파일을 읽는 여러가지 방법
# * readline 함수 이용하기
# * readlines 함수 사용하기
# * read 함수 사용하기
# * 파일 객체를 for 문과 함께 사용하기
#
# readline 함수 이용하기
# * 파일에서 한줄 읽기

# %%
#readline_test.py
f = open("C:/doit/새파일.txt", 'r')
line = f.readline()
print(line)
f.close()
# Out:
# 1번째 줄입니다.

# %% [markdown]
# 위 프로그램을 실행했을 때 새파일.txt 파일의 가장 첫 번쨰 줄이 화면에 출력될 것이다.
# 만약 모든 줄을 읽어 화면에 출려갛고 싶다면 다음과 같이 작성하면 된다.

# %%
# readline_all.py
f = open("C:/doit/새파일.txt", 'r')
while True:
    line = f.readline()
    if not line:
        break
    print(line)
f.close()
# Out:
# 1번째 줄입니다.
#
# 2번째 줄입니다.
#
# 3번째 줄입니다.
#
# 4번째 줄입니다.
#
# 5번째 줄입니다.
#
# 6번째 줄입니다.
#
# 7번째 줄입니다.
#
# 8번째 줄입니다.
#
# 9번째 줄입니다.
#
# 10번째 줄입니다.

# %% [markdown]
# readlines 함수 사용하기

# %%
# readlines.py
f = open("C:/doit/새파일.txt", 'r')
lines = f.readlines()
for line in lines:
    print(line)
f.close()
# Out:
# 1번째 줄입니다.
#
# 2번째 줄입니다.
#
# 3번째 줄입니다.
#
# 4번째 줄입니다.
#
# 5번째 줄입니다.
#
# 6번째 줄입니다.
#
# 7번째 줄입니다.
#
# 8번째 줄입니다.
#
# 9번째 줄입니다.
#
# 10번째 줄입니다.

# %% [markdown]
# 줄 바꿈(\n) 문자 제거하기

# %%
f = open("C:/doit/새파일.txt", 'r')
lines = f.readlines()
for line in lines:
    line = line.strip()  # 줄 끝의 줄 바꿈 문자를 제거한다.
    print(line)
f.close()
# Out:
# 1번째 줄입니다.
# 2번째 줄입니다.
# 3번째 줄입니다.
# 4번째 줄입니다.
# 5번째 줄입니다.
# 6번째 줄입니다.
# 7번째 줄입니다.
# 8번째 줄입니다.
# 9번째 줄입니다.
# 10번째 줄입니다.

# %% [markdown]
# read 함수 사용하기

# %%
# read.py
f = open("C:/doit/새파일.txt", 'r')
data = f.read()
print(data)
f.close()
# Out:
# 1번째 줄입니다.
# 2번째 줄입니다.
# 3번째 줄입니다.
# 4번째 줄입니다.
# 5번째 줄입니다.
# 6번째 줄입니다.
# 7번째 줄입니다.
# 8번째 줄입니다.
# 9번째 줄입니다.
# 10번째 줄입니다.

# %% [markdown]
# 파일 객체를 for 문과 함께 사용하기

# %%
# read_for.py
f = open("C:/doit/새파일.txt", 'r')
for line in f:
    print(line)
f.close()
# Out:
# 1번째 줄입니다.
#
# 2번째 줄입니다.
#
# 3번째 줄입니다.
#
# 4번째 줄입니다.
#
# 5번째 줄입니다.
#
# 6번째 줄입니다.
#
# 7번째 줄입니다.
#
# 8번째 줄입니다.
#
# 9번째 줄입니다.
#
# 10번째 줄입니다.

# %% [markdown]
# ### 파일에 새로운 내용 추가하기
# * 쓰기모드 ('w')로 파일을 열 때 이미 존재하는 파일을 열면 그 파일의 내용이 모두 사라진다.
# * 하지만 원래 있더 값을 유지하면서 새로운 값만 추가해야할 경우도 있다.
# * 이런 경우에는 파일을 추가모드 ('a')로 열면 된다.

# %%
# add_data.py
f = open("C:/doit/새파일.txt",'a')
for i in range(11, 21):
    data = f"{i}번째 줄입니다.\n"
    f.write(data)
f.close()

# %% [markdown]
# with 문과 함께 사용하기
# * 파일을 열면(open) 항상 닫아(close) 주어야 한다.
# * 파이썬의 with 문이 바로 이런 역할을 해 준다.

# %%
# file_with.py
with open("foo.txt", "w") as f:
    f.write("Life is too short, you need python")

# %%
with open("foo.txt", "w") as f:
    f.write("Hello")
    print(f.closed)  # False (아직 열려 있음)

print(f.closed)  # True (with 블록을 벗어나 자동으로 닫힘)
# Out:
# False
# True

# %% [markdown]
# with 문 안에서 만든 변수 사용하기
# * with 문 안에서 만든 변수는 with 블록이 끝난 후에도 사용할 수 있다, 다음 예를 보자

# %%
with open("test.txt", "w") as f:
    content = "Hello, Python!"
    f.write(content)

print(content)  # "Hello, Python!" 출력
# Out:
# Hello, Python!

# %% [markdown]
# 파일 처리 시 주의 사항
# * 한글이 포함된 파일을 다룰 때는 인코딩을 명시하는 것이 좋다.

# %%
# 한글 파일 쓰기
with open("한글파일.txt", "w", encoding="utf-8") as f:
    f.write("안녕하세요, 파이썬!")

# 한글 파일 읽기
with open("한글파일.txt", "r", encoding="utf-8") as f:
    content = f.read()
    print(content)
# Out:
# 안녕하세요, 파이썬!
